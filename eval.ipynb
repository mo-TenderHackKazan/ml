# %%
import pandas as pd


df = pd.read_csv('./outdata.csv')

# %%
df[df['label_text'].isna()]['log'].tolist()
# Out:
# ["Could not execute command: DELETE FROM [dbo].[JobStatus] WHERE TypeName <> 'Granit.Cssp.Jobs.Sku.SkuImportJob' AND CreateDate <= DATEADD(DAY,-30, GETDATE())",
#  'An exception has occurred in the task of verification soon expire user machine readable powers of attorney',
#  'An exception has occurred in the task of verification soon expire user machine readable powers of attorney',
# ...

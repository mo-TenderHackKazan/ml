# %%
import pandas as pd


df = pd.read_csv('outdata.csv')

# %%
lst = df[df['label_text'].isna()]['log'].tolist()
sorted_lst = list(sorted(map(
    lambda x: (lst[x], x), range(len(lst))
), key=lambda x: x[0]))
sorted_lst
# Out:
# [("'_x0002_', hexadecimal value 0x02, is an invalid character.", 32),
#  ("'_x0002_', hexadecimal value 0x02, is an invalid character.", 33),
#  ("'_x0002_', hexadecimal value 0x02, is an invalid character.", 34),
#  ("'_x0002_', hexadecimal value 0x02, is an invalid character.", 35),
#  ("'_x0002_', hexadecimal value 0x02, is an invalid character.", 36),
#  ("'_x0002_', hexadecimal value 0x02, is an invalid character.", 37),
#  ("'_x0002_', hexadecimal value 0x02, is an invalid character.", 38),
#  ("'_x0002_', hexadecimal value 0x02, is an invalid character.", 39),
#  ("'_x0002_', hexadecimal value 0x02, is an invalid character.", 44),
#  ("'_x0002_', hexadecimal value 0x02, is an invalid character.", 54),
#  ("'_x0002_', hexadecimal value 0x02, is an invalid character.", 74),
#  ("'_x0002_', hexadecimal value 0x02, is an invalid character.", 407),
#  ("'_x0002_', hexadecimal value 0x02, is an invalid character.", 408),
# ...

# %%
f = [("hex value is an invalid character", 32),
 ("hex value is an invalid character", 33),
 ("hex value is an invalid character", 34),
 ("hex value is an invalid character", 35),
 ("hex value is an invalid character", 36),
 ("hex value is an invalid character", 37),
 ("hex value is an invalid character", 38),
 ("hex value is an invalid character", 39),
 ("hex value is an invalid character", 44),
 ("hex value is an invalid character", 54),
 ("hex value is an invalid character", 74),
 ("hex value is an invalid character", 407),
 ("hex value is an invalid character", 408),
 ("hex value is an invalid character", 409),
 ("hex value is an invalid character", 410),
 ("hex value is an invalid character", 411),
 ("hex value is an invalid character", 412),
 ("hex value is an invalid character", 413),
 ("hex value is an invalid character", 414),
 ("hex value is an invalid character", 416),
 ("hex value is an invalid character", 424),
 ('SkuOfferMatchResult', 348),
 ('SkuOfferMatchResult', 354),
 ('SkuOfferMatchResult', 360),
 ('SkuOfferMatchResult', 367),
 ('SkuOfferMatchResult', 370),
 ('An error has occurred in the task of publish expiring certificates events',
  380),
 ('An error occurred during stat collection', 196),
 ('An error occurred during stat collection', 198),
 ('An error occurred during stat collection', 336),
 ('An error occurred during stat collection', 337),
 ('An error occurred during stat collection', 338),
 ('An error occurred during stat collection', 341),
 ('An error occurred during stat collection', 342),
 ('An error occurred during stat collection', 343),
 ('An error occurred during stat collection', 346),
 ('An error occurred during stat collection', 349),
 ('An error occurred during stat collection', 350),
 ('An error occurred during stat collection', 351),
 ('An error occurred during stat collection', 355),
 ('An error occurred during stat collection', 356),
 ('An error occurred during stat collection', 362),
 ('An error occurred during stat collection', 363),
 ('An error occurred during stat collection', 364),
 ('An error occurred during stat collection', 365),
 ('An error occurred during stat collection', 371),
 ('An error occurred during stat collection', 374),
 ('An error occurred during stat collection', 375),
 ('An error occurred during stat collection', 376),
 ('An error occurred during stat collection', 377),
 ('An error occurred during stat collection', 385),
 ('task of verification soon expire user machine readable powers of attorney',
  1),
 ('task of verification soon expire user machine readable powers of attorney',
  2),
 ('task of verification soon expire user machine readable powers of attorney',
  4),
 ('task of verification soon expire user machine readable powers of attorney',
  5),
 ('task of verification soon expire user machine readable powers of attorney',
  6),
 ('task of verification soon expire user machine readable powers of attorney',
  7),
 ('task of verification soon expire user machine readable powers of attorney',
  8),
 ('task of verification soon expire user machine readable powers of attorney',
  9),
 ('task of verification soon expire user machine readable powers of attorney',
  10),
 ('task of verification soon expire user machine readable powers of attorney',
  344),
 ('task of verification soon expire user machine readable powers of attorney',
  345),
 ("Database execution failed NHibernate/Pp2.Models.CsspContext",
  14),
 ("Database execution failed NHibernate/Pp2.Models.CsspContext",
  15),
 ("Database execution failed NHibernate/Pp2.Models.CsspContext",
  16),
 ("Database execution failed NHibernate/Pp2.Models.CsspContext",
  17),
 ('OfferExpirationNotificationJob',
  339),
 ('OfferExpirationNotificationJob',
  340),
 ("Could not execute query",
  0),
 ("Could not execute query",
  141),
 ("Could not execute query",
  182),
 ("Could not execute query",
  283),
 ("Could not execute query",
  322),
 ("Could not execute query",
  396),
 ('Could not execute query',
  183),
 ('Could not execute query',
  323),
 ('Could not execute query',
  327),
 ('Could not execute query',
  397),
 ('Could not execute query',
  185),
 ('Could not execute query',
  189),
 ('Could not execute query',
  329),
 ('Could not execute query',
  192),
 ('Could not execute query',
  194),
 ('Could not execute query',
  334),
 ('Could not execute query',
  400),
 ('Could not execute query',
  203),
 ('Could not execute query',
  357),
 ('Could not synchronize database state with session', 175),
 ('Could not synchronize database state with session', 176),
 ('Could not synchronize database state with session', 177),
 ('Could not synchronize database state with session', 178),
 ('Could not synchronize database state with session', 179),
 ('Could not synchronize database state with session', 191),
 ('Could not synchronize database state with session', 199),
 ('Could not synchronize database state with session', 200),
 ('Could not synchronize database state with session', 201),
 ('Could not synchronize database state with session', 202),
 ('Could not synchronize database state with session', 205),
 ('Could not synchronize database state with session', 206),
 ('Could not synchronize database state with session', 207),
 ('Could not synchronize database state with session', 208),
 ('Could not synchronize database state with session', 319),
 ('Could not synchronize database state with session', 333),
 ('Could not synchronize database state with session', 384),
 ('Could not synchronize database state with session', 399),
 ("Failed executing DbCommand",
  3),
 ("Failed executing DbCommand",
  294),
 ("Failed executing DbCommand",
  197),
 ("Failed executing DbCommand",
  174),
 ("Failed executing DbCommand",
  108),
 ("Failed executing DbCommand",
  112),
 ("Failed executing DbCommand",
  106),
 ("Failed executing DbCommand",
  107),
 ("Failed executing DbCommand",
  113),
 ('Failed executing DbCommand',
  249),
 ('Failed executing DbCommand',
  264),
 ('Failed executing DbCommand',
  257),
 ('Failed executing DbCommand',
  253),
 ('Failed executing DbCommand',
  247),
 ("Failed executing DbCommand",
  111),
 ("Failed executing DbCommand",
  114),
 ("Failed executing DbCommand",
  115),
 ('Failed executing DbCommand',
  23),
 ('Failed executing DbCommand',
  243),
 ('Failed executing DbCommand',
  245),
 ('Failed executing DbCommand',
  251),
 ('Failed executing DbCommand',
  260),
 ('Failed executing DbCommand',
  241),
 ('Failed executing DbCommand',
  262),
 ("Failed executing DbCommand",
  402),
 ("Failed executing DbCommand",
  347),
 ("Failed executing DbCommand",
  353),
 ("Failed executing DbCommand",
  366),
 ("Failed executing DbCommand",
  359),
 ("Failed executing DbCommand",
  369),
 ('Failed executing DbCommand',
  255),
 ('Failed executing DbCommand',
  167),
 ('Failed executing DbCommand',
  239),
 ("Failed executing DbCommand",
  105),
 ("Could not execute query", 165),
 ("Could not execute query", 166),
 ("Could not execute query", 170),
 ('Kaluga error',
  142),
 ('Kaluga error',
  140),
 ('Kaluga error',
  318),
 ('Kaluga error',
  122),
 ('Kaluga error',
  279),
 ('Kaluga error',
  139),
 ('OpComplete error',
  268),
 ('OpComplete error',
  238),
 ('OpComplete error',
  81),
 ("OpComplete error",
  91),
 ("OpComplete error",
  93),
 ("OpComplete error",
  173),
 ("OpComplete error",
  157),
 ("OpComplete error",
  94),
 ('OpComplete error',
  270),
 ('OpComplete error',
  282),
 ('OpComplete error',
  53),
 ('OpComplete error',
  274),
 ('OpComplete error',
  281),
 ('Could not execute query',
  418),
 ('The handle is invalid', 11),
 ('The handle is invalid', 12),
 ('The handle is invalid', 144),
 ('The handle is invalid', 212),
 ('The handle is invalid', 236),
 ('The handle is invalid', 237),
 ('The handle is invalid', 378),
 ('The handle is invalid', 379),
 ('The handle is invalid', 403),
 ('Unable to SendResult CreateAuction',
  152),
 ('Unable to SendResult CreateAuction',
  153),
 ('Unable to SendResult CreateAuction',
  154),
 ('Unable to SendResult CreateAuction',
  156),
 ('Unable to SendResult CreateAuction',
  158),
 ('Unable to SendResult CreateAuction',
  180),
 ('Unable to SendResult CreateAuction',
  45),
 ('Unable to SendResult CreateAuction',
  46),
 ('Unable to SendResult CreateAuction',
  52),
 ('Unable to SendResult CreateAuction',
  73),
 ('Unable to SendResult CreateAuction',
  143),
 ('Unable to SendResult CreateAuction',
  298),
 ('Unable to SendResult CreateAuction',
  300),
 ('Unable to SendResult CreateAuction',
  302),
 ('Unable to SendResult CreateAuction',
  304),
 ('Unable to SendResult CreateAuction',
  310),
 ('Unable to SendResult CreateAuction',
  299),
 ('Unable to SendResult CreateAuction',
  301),
 ('Unable to SendResult CreateAuction',
  303),
 ('Unable to SendResult CreateAuction',
  305),
 ('Unable to SendResult CreateAuction',
  311),
 ('OperationComplete', 67),
 ('OperationComplete', 72),
 ('OperationComplete', 80),
 ('OperationComplete', 89),
 ('OperationComplete', 90),
 ('OperationComplete', 95),
 ('OperationComplete', 163),
 ('OperationComplete', 278),
 ('Unable to parse request', 276),
 ('Unable to parse request',
  275),
 ('Unable to parse request',
  271),
 ('Unable to parse request',
  273),
 ('Unable to parse request',
  269),
 ('Unable to parse request',
  272),
 ('Unable to send AuctionFinished',
  259),
 ('Unable to send AuctionFinished',
  422),
 ('Unable to send AuctionFinished',
  423),
 ('Unable to send AuctionFinished',
  425),
 ('Unable to send AuctionFinished',
  169),
 ('Unable to send AuctionFinished',
  426),
 ('Unable to send company reg request', 155),
 ('Unable to send contract execution',
  77),
 ('Unable to set failed for command',
  187),
 ('Unable to upload files', 68),
 ('Unable to upload files', 69),
 ('Unable to upload files', 70),
 ('Unable to upload files', 71),
 ('Unable to upload files', 159),
 ('Unable to upload files', 160),
 ('Unable to upload files', 161),
 ('Unable to upload files', 162),
 ('Unable to upload files', 306),
 ('Unable to upload files', 307),
 ('Unable to upload files', 308),
 ('Unable to upload files', 309),
 ('Unable to upload files', 391),
 ('Unable to upload files', 392),
 ('Unable to upload files', 393),
 ('Unable to upload files', 394),
 ('Unable to upload files', 28),
 ('Unable to upload files', 147),
 ('Unable to upload files', 226),
 ('Unable to upload files', 297),
 ('Unable to upload files', 390),
 ('Unable to upload files', 406),
 ('Данные не могут быть проимпортированы или обработаны || 03001a006fea2700-38870960, PackageDateTime : 09.10.2023 21:11:11 +00:00',
  130),
 ('Данные не могут быть проимпортированы или обработаны || 03001a006fea2700-38870961, PackageDateTime : 09.10.2023 21:11:11 +00:00',
  129),
 ('Данные не могут быть проимпортированы или обработаны || 07001600887e2800-38871804, PackageDateTime : 12.10.2023 9:34:15 +00:00',
  228),
 ('Данные не могут быть проимпортированы или обработаны || 0b000c0059842600-38870642, PackageDateTime : 09.10.2023 11:24:15 +00:00',
  42),
 ('Данные не могут быть проимпортированы или обработаны || 0b000c0059842600-38870643, PackageDateTime : 09.10.2023 11:24:15 +00:00',
  43),
 ('Данные не могут быть проимпортированы или обработаны || 0f001100cb5b2f00-38870560, PackageDateTime : 09.10.2023 8:41:13 +00:00',
  25),
 ('Данные не могут быть проимпортированы или обработаны || 11001e00d25f2100-38870985, PackageDateTime : 09.10.2023 21:27:09 +00:00',
  136),
 ('Данные не могут быть проимпортированы или обработаны || 16000300aee42900-38870879, PackageDateTime : 09.10.2023 15:52:11 +00:00',
  85),
 ('Данные не могут быть проимпортированы или обработаны || 16000300aee42900-38870879, PackageDateTime : 09.10.2023 15:52:11 +00:00',
  86),
 ('Данные не могут быть проимпортированы или обработаны || 16000300aee42900-38870880, PackageDateTime : 09.10.2023 15:52:11 +00:00',
  84),
 ('Данные не могут быть проимпортированы или обработаны || 1d000d003a371500-38870979, PackageDateTime : 09.10.2023 21:08:13 +00:00',
  124),
 ('Данные не могут быть проимпортированы или обработаны || 1d000d003a371500-38870979, PackageDateTime : 09.10.2023 21:08:13 +00:00',
  125),
 ('Данные не могут быть проимпортированы или обработаны || d80e1d00d4ee0400-38870624, PackageDateTime : 09.10.2023 9:57:18 +00:00',
  29),
 ('Данные не могут быть проимпортированы или обработаны || d80e1d00d4ee0400-38870624, PackageDateTime : 09.10.2023 9:57:18 +00:00',
  30),
 ('Данные не могут быть проимпортированы или обработаны || db0e0a00a3d30400-2494474, PackageDateTime : 14.10.2023 23:28:32 +00:00',
  386),
 ('Данные не могут быть проимпортированы или обработаны || dd0e1400eff40400-8606127, PackageDateTime : 14.10.2023 23:11:20 +00:00',
  332),
 ('Данные не могут быть проимпортированы или обработаны || df0e20000bd60400-3769038, PackageDateTime : 14.10.2023 23:09:32 +00:00',
  325),
 ('Данные не могут быть проимпортированы или обработаны || Данный пакет уже был импортирован. PackageGuid : 36784198, PackageDateTime : 15.10.2023 2:01:32 +03:00',
  326),
 ('Данные не могут быть проимпортированы или обработаны || Данный пакет уже был импортирован. PackageGuid : 36786562, PackageDateTime : 15.10.2023 2:29:53 +03:00',
  331),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  26),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  31),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  48),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  56),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  57),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  58),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  59),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  60),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  66),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  78),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  87),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  97),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  126),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  131),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  133),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  135),
 ('Данные не могут быть проимпортированы или обработаны || Нельзя импортировать характеристики неактуального КПГЗ',
  138),
 ('Невозможно написать текст ошибки || 00fa120e-fbe0-4d7b-bce9-72df19669ab3 невозможно записать текст ошибки в поле LastException',
  387),
 ('Невозможно написать текст ошибки || 00fa120e-fbe0-4d7b-bce9-72df19669ab3 невозможно записать текст ошибки в поле LastException',
  388),
 ('Невозможно написать текст ошибки || 1a4f421b-d86f-44f4-b037-b345a036396c невозможно записать текст ошибки в поле LastException',
  19),
 ('Невозможно написать текст ошибки || 1c8734fc-2fbf-4b63-9da8-9718aaf5bdb6 невозможно записать текст ошибки в поле LastException',
  188),
 ('Невозможно написать текст ошибки || 553ed3a0-ce07-4f6f-ade4-54415be0eaf1 невозможно записать текст ошибки в поле LastException',
  20),
 ('Невозможно написать текст ошибки || 63b3d3a8-ef36-477e-a33e-d5426f961d65 невозможно записать текст ошибки в поле LastException',
  21),
 ('Невозможно написать текст ошибки || 63b3d3a8-ef36-477e-a33e-d5426f961d65 невозможно записать текст ошибки в поле LastException',
  22),
 ('Невозможно написать текст ошибки || 63b3d3a8-ef36-477e-a33e-d5426f961d65 невозможно записать текст ошибки в поле LastException',
  148),
 ('Невозможно написать текст ошибки || 63b3d3a8-ef36-477e-a33e-d5426f961d65 невозможно записать текст ошибки в поле LastException',
  149),
 ('Невозможно написать текст ошибки || cd0f2b7b-4a69-4d49-a7f2-08a6c10787bd невозможно записать текст ошибки в поле LastException',
  389),
 ('МЧД: подписание по старому сертификату || 2086295942', 171),
 ('МЧД: подписание по старому сертификату || 2086296246', 277),
 ('МЧД: подписание по старому сертификату || 2086296254', 280),
 ('Не найден КПГЗ || с Id: 38870541. Запрашиваем дополнительно', 27),
 ('Не найден КПГЗ || с Id: 38870559. Запрашиваем дополнительно', 24),
 ('Не найден КПГЗ || с Id: 38870642. Запрашиваем дополнительно', 40),
 ('Не найден КПГЗ || с Id: 38870642. Запрашиваем дополнительно', 41),
 ('Не найден КПГЗ || с Id: 38870659. Запрашиваем дополнительно', 47),
 ('Не найден КПГЗ || с Id: 38870679. Запрашиваем дополнительно', 49),
 ('Не найден КПГЗ || с Id: 38870699. Запрашиваем дополнительно', 55),
 ('Не найден КПГЗ || с Id: 38870827. Запрашиваем дополнительно', 75),
 ('Не найден КПГЗ || с Id: 38870879. Запрашиваем дополнительно', 82),
 ('Не найден КПГЗ || с Id: 38870879. Запрашиваем дополнительно', 83),
 ('Не найден КПГЗ || с Id: 38870906. Запрашиваем дополнительно', 96),
 ('Не найден КПГЗ || с Id: 38870960. Запрашиваем дополнительно', 127),
 ('Не найден КПГЗ || с Id: 38870960. Запрашиваем дополнительно', 128),
 ('Не найден КПГЗ || с Id: 38870979. Запрашиваем дополнительно', 123),
 ('Не найден КПГЗ || с Id: 38870981. Запрашиваем дополнительно', 132),
 ('Не найден КПГЗ || с Id: 38870983. Запрашиваем дополнительно', 134),
 ('Не найден КПГЗ || с Id: 38870985. Запрашиваем дополнительно', 137),
 ('Не найден КПГЗ || с Id: 38871804. Запрашиваем дополнительно', 227),
 ('Не найден КПГЗ || с Id: 38871853. Запрашиваем дополнительно', 229),
 ('Не найден КПГЗ || с Id: 38871958. Запрашиваем дополнительно', 230),
 ('Невозможно отправить результаты комнады "КС: Создание совместной закупки" || feeb57a0-92e5-4b99-9e4c-5baacfd252c5',
  98),
 ('Невозможно отправить результаты комнады "КС: Создание совместной закупки" || feeb57a0-92e5-4b99-9e4c-5baacfd252c5',
  99),
 ('Невозможно отправить результаты комнады "КС: Создание совместной закупки" || feeb57a0-92e5-4b99-9e4c-5baacfd252c5',
  100),
 ('Невозможно отправить результаты комнады "КС: Создание совместной закупки" || feeb57a0-92e5-4b99-9e4c-5baacfd252c5',
  119),
 ('Необработанная ошибка валидации МЧД попытка добавления дубликата || \'{"MachineReadablePowerOfAttorneyFileStorageId":2086295916, "UserCompanyId":31563053, "InitiatorSystemUserId":20048012, "InitiatorSpUserId":19696828}\'',
  168),
 ('Необработанная ошибка валидации МЧД попытка добавления дубликата || \'{"MachineReadablePowerOfAttorneyFileStorageId":2086296138, "UserCompanyId":28401450, "InitiatorSystemUserId":20047900, "InitiatorSpUserId":19696717, "MachineReadablePowerOfAttorneyOwnerId":20048021}\'',
  240),
 ('Необработанная ошибка валидации МЧД попытка добавления дубликата || \'{"MachineReadablePowerOfAttorneyFileStorageId":2086296143, "UserCompanyId":28401450, "InitiatorSystemUserId":20047900, "InitiatorSpUserId":19696717, "MachineReadablePowerOfAttorneyOwnerId":20048021}\'',
  242),
 ('Необработанная ошибка валидации МЧД попытка добавления дубликата || \'{"MachineReadablePowerOfAttorneyFileStorageId":2086296145, "UserCompanyId":28401450, "InitiatorSystemUserId":20047900, "InitiatorSpUserId":19696717, "MachineReadablePowerOfAttorneyOwnerId":20048021}\'',
  244),
 ('Необработанная ошибка валидации МЧД попытка добавления дубликата || \'{"MachineReadablePowerOfAttorneyFileStorageId":2086296146, "UserCompanyId":28401450, "InitiatorSystemUserId":20047900, "InitiatorSpUserId":19696717, "MachineReadablePowerOfAttorneyOwnerId":20048021}\'',
  246),
 ('Необработанная ошибка валидации МЧД попытка добавления дубликата || \'{"MachineReadablePowerOfAttorneyFileStorageId":2086296154, "UserCompanyId":28401450, "InitiatorSystemUserId":20047900, "InitiatorSpUserId":19696717, "MachineReadablePowerOfAttorneyOwnerId":20048021}\'',
  248),
 ('Необработанная ошибка валидации МЧД попытка добавления дубликата || \'{"MachineReadablePowerOfAttorneyFileStorageId":2086296168, "UserCompanyId":31563053, "InitiatorSystemUserId":20039503, "InitiatorSpUserId":19688363, "MachineReadablePowerOfAttorneyOwnerId":20048024}\'',
  250),
 ('Необработанная ошибка валидации МЧД попытка добавления дубликата || \'{"MachineReadablePowerOfAttorneyFileStorageId":2086296169, "UserCompanyId":31563053, "InitiatorSystemUserId":20039503, "InitiatorSpUserId":19688363, "MachineReadablePowerOfAttorneyOwnerId":20048024}\'',
  252),
 ('Необработанная ошибка валидации МЧД попытка добавления дубликата || \'{"MachineReadablePowerOfAttorneyFileStorageId":2086296172, "UserCompanyId":31563053, "InitiatorSystemUserId":20039503, "InitiatorSpUserId":19688363, "MachineReadablePowerOfAttorneyOwnerId":20048024}\'',
  254),
 ('Необработанная ошибка валидации МЧД попытка добавления дубликата || \'{"MachineReadablePowerOfAttorneyFileStorageId":2086296191, "UserCompanyId":31563053, "InitiatorSystemUserId":20039503, "InitiatorSpUserId":19688363, "MachineReadablePowerOfAttorneyOwnerId":20048024}\'',
  256),
 ('Необработанная ошибка валидации МЧД попытка добавления дубликата || \'{"MachineReadablePowerOfAttorneyFileStorageId":2086296193, "UserCompanyId":31563053, "InitiatorSystemUserId":20039503, "InitiatorSpUserId":19688363, "MachineReadablePowerOfAttorneyOwnerId":20048024}\'',
  258),
 ('Необработанная ошибка валидации МЧД попытка добавления дубликата || \'{"MachineReadablePowerOfAttorneyFileStorageId":2086296194, "UserCompanyId":31563053, "InitiatorSystemUserId":20048027, "InitiatorSpUserId":19696843}\'',
  261),
 ('Необработанная ошибка валидации МЧД попытка добавления дубликата || \'{"MachineReadablePowerOfAttorneyFileStorageId":2086296195, "UserCompanyId":31563053, "InitiatorSystemUserId":20048027, "InitiatorSpUserId":19696843}\'',
  263),
 ('Необработанная ошибка валидации МЧД попытка добавления дубликата || \'{"MachineReadablePowerOfAttorneyFileStorageId":2086296196, "UserCompanyId":31563053, "InitiatorSystemUserId":20039503, "InitiatorSpUserId":19688363, "MachineReadablePowerOfAttorneyOwnerId":20048027}\'',
  265),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  61),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  62),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  63),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  64),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  65),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  216),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  217),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  218),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  219),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  220),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  221),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  222),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  223),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  224),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  225),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  231),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  232),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  233),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  234),
 ('Ошибка авторизации в интеграционном апи ||. Login: 611512382b274209898df6391e2b5f2c, Password: a6285a6db5ec4c84857f016ae698844e962197b6c8104568a00bb93defd8510b',
  235),
 ('Ошибка доступа к сервису капчи', 421),
 ('Ошибка запроса получения информации об операции интеграции',
  50),
 ('Ошибка запроса получения информации об операции интеграции',
  51),
 ('Ошибка запроса статуса самозанятого', 13),
 ('Ошибка запроса статуса самозанятого', 18),
 ('Ошибка запроса статуса самозанятого', 145),
 ('Ошибка запроса статуса самозанятого', 146),
 ('Ошибка запроса статуса самозанятого', 213),
 ('Ошибка запроса статуса самозанятого', 214),
 ('Ошибка запроса статуса самозанятого', 295),
 ('Ошибка запроса статуса самозанятого', 296),
 ('Ошибка запроса статуса самозанятого', 382),
 ('Ошибка запроса статуса самозанятого', 383),
 ('Ошибка запроса статуса самозанятого', 404),
 ('Ошибка запроса статуса самозанятого', 405),
 ('Ошибка индексации оферт', 209),
 ('Ошибка индексации оферт', 210),
 ('Ошибка индексации оферт', 211),
 ('Ошибка обработки события измнения сущности',
  267),
 ('Ошибка обращения к api внешней системы || ЕГРЮЛ ДИТ',
  164),
 ('Ошибка обращения к api внешней системы || ЕГРЮЛ ДИТ',
  415),
 ('Ошибка обращения к api внешней системы || ЕГРЮЛ ДИТ. Код ошибки: NotFound. Запрос: https://papi.mos.ru/api/egrulv2/1.0/egrul?inn=7999991111',
  427),
 ('Ошибка обращения к api внешней системы || ЕГРЮЛ ДИТ. Код ошибки: NotFound. Запрос: https://papi.mos.ru/api/egrulv2/1.0/egrul?inn=8999991111',
  417),
 ('Ошибка обращения к api внешней системы || ЕГРЮЛ ДИТ. Код ошибки: NotFound. Запрос: https://papi.mos.ru/api/egrulv2/1.0/egrul?inn=9876512366',
  79),
 ('Ошибка при вызове сервиса ЕИС', 150),
 ('Ошибка при вызове сервиса ЕИС', 312),
 ('Ошибка при вызове сервиса ЕИС', 314),
 ('Ошибка при вызове сервиса ЕИС', 316),
 ('Ошибка при вызове сервиса ЕИС', 317),
 ('Ошибка при запросе списка интеграционного обмена', 419),
 ('Ошибка при запросе списка интеграционного обмена', 420),
 ('Ошибка при обращении к сервису ЕИС',
  313),
 ('Ошибка при обращении к сервису ЕИС',
  315),
 ('Ошибка при обращении к сервису ЕИС', 151),
 ('Ошибка при поиске неиндексированных сущностей', 181),
 ('Ошибка при поиске неиндексированных сущностей', 320),
 ('Ошибка при поиске неиндексированных сущностей', 321),
 ('Ошибка при поиске неиндексированных сущностей', 395),
 ('Ошибка при поиске неиндексированных сущностей', 184),
 ('Ошибка при поиске неиндексированных сущностей', 186),
 ('Ошибка при поиске неиндексированных сущностей', 324),
 ('Ошибка при поиске неиндексированных сущностей', 328),
 ('Ошибка при поиске неиндексированных сущностей', 398),
 ('Ошибка при поиске неиндексированных сущностей', 372),
 ('Ошибка при поиске неиндексированных сущностей', 190),
 ('Ошибка при поиске неиндексированных сущностей', 330),
 ('Ошибка при поиске неиндексированных сущностей', 193),
 ('Ошибка при поиске неиндексированных сущностей', 195),
 ('Ошибка при поиске неиндексированных сущностей', 335),
 ('Ошибка при поиске неиндексированных сущностей', 401),
 ('Ошибка при поиске неиндексированных сущностей', 204),
 ('Ошибка при поиске неиндексированных сущностей', 358),
 ('Ошибка при расчёте достижений компании.', 352),
 ('Ошибка при расчёте достижений компании.', 361),
 ('Ошибка при расчёте достижений компании.', 368),
 ('Ошибка при расчёте достижений компании.', 373),
 ('Ошибка публикации события об окончании срока действия сертификата пользователя',
  381),
 ('ошибка импорта ||  14.12.21.120 для записи с ExternalId=1039\\56\\2023" для ExternalId=1039\\56\\2023. Пропускаем запись. Проимпортировано 0 записей. ',
  284),
 ('ошибка импорта ||  14.12.21.120 для записи с ExternalId=1039\\57\\2023" для ExternalId=1039\\57\\2023. Пропускаем запись. Проимпортировано 0 записей. ',
  285),
 ('ошибка импорта ||  14.12.21.120 для записи с ExternalId=1039\\58\\2023" для ExternalId=1039\\58\\2023. Пропускаем запись. Проимпортировано 0 записей. ',
  286),
 ('ошибка импорта ||  26.51.45.190 для записи с ExternalId=5750\\1\\2022" для ExternalId=5750\\1\\2022. Пропускаем запись. Проимпортировано 2666 записей. ',
  290),
 ('ошибка импорта ||  26.51.45.190 для записи с ExternalId=5750\\2\\2022" для ExternalId=5750\\2\\2022. Пропускаем запись. Проимпортировано 2666 записей. ',
  291),
 ('ошибка импорта ||  26.51.45.190 для записи с ExternalId=5750\\3\\2022" для ExternalId=5750\\3\\2022. Пропускаем запись. Проимпортировано 2666 записей. ',
  292),
 ('ошибка импорта ||  26.51.45.190 для записи с ExternalId=5750\\5\\2022" для ExternalId=5750\\5\\2022. Пропускаем запись. Проимпортировано 2666 записей. ',
  293),
 ('ошибка импорта ||  28.93.17.120 для записи с ExternalId=564\\5\\2023" для ExternalId=564\\5\\2023. Пропускаем запись. Проимпортировано 2666 записей. ',
  288),
 ('ошибка импорта ||  28.93.17.120 для записи с ExternalId=564\\6\\2023" для ExternalId=564\\6\\2023. Пропускаем запись. Проимпортировано 2666 записей. ',
  289),
 ('ошибка импорта || 15.11.1. для записи с ExternalId=167\\1\\2023" для ExternalId=167\\1\\2023. Пропускаем запись. Проимпортировано 253 записей. ',
  287),
 ('Реиндексация компаний завершилась с ошибкой', 215),
 ('Событие обработано с ошибками',
  172),
 ('На диске нету файла',
  88),
 ('На диске нету файла',
  92),
 ('На диске нету файла',
  101),
 ('На диске нету файла',
  102),
 ('На диске нету файла',
  103),
 ('На диске нету файла',
  104),
 ('На диске нету файла',
  109),
 ('На диске нету файла',
  110),
 ('На диске нету файла',
  116),
 ('На диске нету файла',
  117),
 ('На диске нету файла',
  118),
 ('На диске нету файла',
  120),
 ('На диске нету файла',
  121),
 ('На диске нету файла',
  266),
 ('На диске нету файла',
  76)]

# %%
f = list(map(
    lambda x: x[0].split(' ||')[0],
    sorted(
        f,
        key=lambda x: x[1]
    )
))

# %%
f
# Out:
# ['Could not execute query',
#  'task of verification soon expire user machine readable powers of attorney',
#  'task of verification soon expire user machine readable powers of attorney',
#  'Failed executing DbCommand',
#  'task of verification soon expire user machine readable powers of attorney',
#  'task of verification soon expire user machine readable powers of attorney',
#  'task of verification soon expire user machine readable powers of attorney',
#  'task of verification soon expire user machine readable powers of attorney',
#  'task of verification soon expire user machine readable powers of attorney',
#  'task of verification soon expire user machine readable powers of attorney',
#  'task of verification soon expire user machine readable powers of attorney',
#  'The handle is invalid',
#  'The handle is invalid',
#  'Ошибка запроса статуса самозанятого',
#  'Database execution failed NHibernate/Pp2.Models.CsspContext',
# ...

# %%
from numpy import nan
lt = df['label_text'].tolist()
nl = []
ptr = 0
for i in lt:
    if i is nan:
        nl.append(f[ptr])
        ptr += 1
    else:
        nl.append(i)

# %%
df['label_text'] = nl

# %%
df.to_csv('outdata.csv')
